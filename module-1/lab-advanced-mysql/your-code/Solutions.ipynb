# %%
import pandas as pd
import sqlalchemy as db
from getpass import getpass

# %%
user = "root"
password = getpass("Insert password: ")
# Out:
# Insert password: ········

# %%
connectionURI = f"mysql+pymysql://{user}:{password}@localhost/publications"

# %%
engine = db.create_engine(connectionURI)
print("Connected to server!")
# Out:
# Connected to server!

# %%
#Part 1

d0 = pd.read_sql_query("""SELECT ta.au_id AUTHOR_ID, ta.title_id TITLE_ID, ROUND(t.price * s.qty *t.royalty/100 * t.royalty/100,2) SALES_ROYALTY
FROM titleauthor ta
	LEFT JOIN titles t ON t.title_id = ta.title_id
    LEFT JOIN sales s ON s.title_id = t.title_id
    ;""",engine)
d0
# Out:
#       AUTHOR_ID TITLE_ID  SALES_ROYALTY
# 0   213-46-8915   BU1032           1.00
# 1   213-46-8915   BU1032           2.00
# 2   409-56-7008   BU1032           1.00
# 3   409-56-7008   BU1032           2.00
# 4   267-41-2394   BU1111           2.99
# 5   724-80-9391   BU1111           2.99
# 6   213-46-8915   BU2075           6.03
# 7   274-80-9391   BU7832           3.00
# 8   712-45-1867   MC2222           2.88
# 9   722-51-5454   MC3021           4.31
# 10  722-51-5454   MC3021           2.58
# 11  899-46-2035   MC3021           4.31
# 12  899-46-2035   MC3021           2.58
# 13  238-95-7766   PC1035          17.63
# 14  427-17-2319   PC8888          10.00
# 15  846-92-7186   PC8888          10.00
# 16  486-29-1786   PC9999            NaN
# 17  724-80-9391   PS1372           4.32
# 18  756-30-7391   PS1372           4.32
# 19  899-46-2035   PS2091           0.47
# 20  899-46-2035   PS2091          11.83
# 21  899-46-2035   PS2091           1.58
# ...

# %%
#Part 2

d1 = pd.read_sql_query("""SELECT AUTHOR_ID, TITLE_ID, SUM(SALES_ROYALTY)

FROM( SELECT ta.au_id AUTHOR_ID, ta.title_id TITLE_ID, ROUND(t.price * s.qty *t.royalty/100 * t.royalty/100,2) SALES_ROYALTY
FROM titleauthor ta
LEFT JOIN titles t ON t.title_id = ta.title_id
LEFT JOIN sales s ON s.title_id = t.title_id) AS total
    ;""",engine)
d0
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#
# /opt/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ...
