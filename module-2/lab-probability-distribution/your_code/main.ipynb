# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Import your libraries
import math
import statistics
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import poisson, binom

# %% [markdown]
# # Challenge 1 - Generate and Plot Normal Distributions

# %% [markdown]
# #### Step 1: Generate samples and test normal distribution
#
# Use mean=50, standard_deviation=5, and sample_size=[10, 50, 500, 5000] to generate 4 random samples that are normally distributed. Test your normal distributions with [`scipy.stats.normaltest`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.normaltest.html).
#
#
# *Hint: Read the documentation for `scipy.stats.normaltest`. The function does not simply return Yes or No for whether your data is normal distribution. It returns the likelihood.*

# %% [raw]
# numpy.random.normal(loc = 0.0, scale = 1.0, size = None)
#
# Parameters :
# loc   : [float or array_like] Mean of the distribution.
# scale : [float or array_like] Standard Derivation of the distribution.
# size  : [int or int tuples].

# %%
mean = 50
sd = 5 
size=[10, 50, 500, 5000]

a = np.random.normal(mean, sd, size[0])
b = np.random.normal(mean, sd, size[1])
c = np.random.normal(mean, sd, size[2])
d = np.random.normal(mean, sd, size[3])

# Aplicamos la fórmula scipy.stats.normaltest

A = stats.normaltest(a)
B = stats.normaltest(b)
C = stats.normaltest(c)
D = stats.normaltest(d)

print(A)
print(B)
print(C)
print(D)

#Al tener todos los valores pval > 0.055 podemos decir que siguen una distribución normal
# Out:
# NormaltestResult(statistic=1.9951856017478111, pvalue=0.36876606695500663)
# NormaltestResult(statistic=1.2768389598662522, pvalue=0.5281264792472273)
# NormaltestResult(statistic=5.297938848904942, pvalue=0.07072406200473559)
# NormaltestResult(statistic=7.026041088299942, pvalue=0.029806745734750523)
# /opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1450: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   "anyway, n=%i" % int(n))

# %% [markdown]
# #### Interpret the normaltest results and make your observations.

# %%
# Explain the test results here

# %% [markdown]
# Stats.normaltest devuelve dos resultados; k y p-value.
#
# Al tener todos los valores pval > 0.055 podemos afirmar que siguen una distribución normal.

# %% [markdown]
# #### Step 2: Plot normal distributions
#
# Use matplotlib subplots to plot a histogram of each sample.
#
# *Hints:*
# - Use subplots to compare your figures side by side.
#
# - Your output should look like below:
#
# ![normal distributions with different sample sizes](ch-1.png)

# %%
plt.style.use('seaborn-dark')

fig, axs = plt.subplots(1, 4, figsize=(18, 6))
axs[0].hist(a,bins=12)
axs[0].title.set_text('Sample Size=10')

axs[1].hist(b,bins=12)
axs[1].title.set_text('Sample Size=50')

axs[2].hist(c,bins=12)
axs[2].title.set_text('Sample Size=500')

axs[3].hist(d,bins=12)
axs[3].title.set_text('Sample Size=5000')

# %%
# Your code here
plt.style.use('seaborn')

fig, axs = plt.subplots(2, 2, figsize=(15, 8))
axs[0, 0].hist(a,bins=10)
axs[0, 1].hist(b,bins=10)
axs[1, 0].hist(c,bins=10)
axs[1, 1].hist(d,bins=10)
# Out:
# (array([   4.,   59.,  228.,  647., 1137., 1350.,  974.,  482.,   99.,
#           20.]),
#  array([31.52890677, 35.03317921, 38.53745166, 42.04172411, 45.54599655,
#         49.050269  , 52.55454145, 56.0588139 , 59.56308634, 63.06735879,
#         66.57163124]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Compare the distributions above. What do you observe? Explain with the Central Limit Theorem.

# %%
# Your comment and explanation here

# %% [markdown]
# Según el teorema central del límite (TCL), dada una muestra suficientemente grande de la población, la distribución de las medias muestrales seguirá una distribución normal.
#
# Lo podemos ver claramente en los gráficos 3 y 4 que con tamaños de muestras significativamente más grandes que los gráficos 1 y 2 su dsitribución se parece a una ditribución normal (mayor concentración de los valores en torno a la media).

# %% [markdown]
# # Challenge 2 - Plot Probability Mass Function (PMF)

# %% [markdown]
# #### Background knowledge
#
# [PMF](https://en.wikipedia.org/wiki/Probability_mass_function) shows the probability distribution of a **discrete random variable**. A [discrete random variable](https://en.wikipedia.org/wiki/Random_variable#Discrete_random_variable) has random numeric values that are not continuous. For example, the number of people in a household can only be integers but not floats. Therefore the number of people in a household is a discrete variable.
#
# #### Question: We assume that the probability of clicking an Ad in a Youtube video is 0.15. We have a sample of 5 people who wathched the video and we want to plot the PMF for a binomial distribution.
#
# *Hint: use binom from `scipy.stats.binom`. Your output should look like below:*
#
# ![binom 10](ch-2.png)

# %%
# Usamos PMF--> pmf(k, mu, loc=0)

x = np.arange(0,6)
sns.lineplot(x, binom.pmf(x,5,0.15))

# %% [markdown]
# #### Explain what you observe from the plot above

# %% [markdown]
# A mayor número de personas menor proabilidad de que pinchen el anuncio

# %%
#la probabilidad de que ninguna persona pinche el enlace es de 0.44
binom.pmf(0,5,0.15)
# Out:
# 0.4437053125

# %%
#la probabilidad de que 5 personas pinchen el enlace
binom.pmf(5,5,0.15)
# Out:
# 7.593750000000001e-05

# %%
#la probabilidad de que 6 personas pinchen el enlace es cero porque la muestra es de 5
binom.pmf(6,5,0.15)
# Out:
# 0.0

# %%
#la probabilidad acumulativa sería:
sns.lineplot(x, binom.cdf(x,5,0.15))

# %% [markdown]
# #### Now plot PMP with 50, 500, and 5000 visitors.

# %%
# Your code here
k= 0,15

x = np.arange(0,50)
sns.lineplot(x, binom.pmf(x,50,0.15))

# %%
x = np.arange(0,500)
sns.lineplot(x, binom.pmf(x,500,0.15))

# %%
x = np.arange(0,500)
sns.lineplot(x, binom.pmf(x,500,0.15))

# %% [markdown]
# #### What did you notice from the distribution plots? Comment your findings.

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Reaserch the Poisson distribution. Write about your own understanding of the Poisson distribution.

# %% [markdown]
# La distribución de Poisson es una distribución de probabilidad discreta que expresa, a partir de una frecuencia de ocurrencia media, la probabilidad de que ocurra un determinado número de eventos durante cierto período de tiempo. Concretamente, se especializa en la probabilidad de ocurrencia de sucesos con probabilidades muy pequeñas, o sucesos «raros».

# %% [markdown]
# #### A website has an average of 300 visits per day. What is the probability of getting 320 visitors in a day?
#
# *Hint: use `scipy.stats.poisson`*

# %%
k= probabilidad de que alguin pinche 
pmf = dist prob de que una determinada cosa pase
cdf= acumulativa

# %%
# Your code here
# mu parameter specifies the mean of successful

mu = 300
k = 320
stats.poisson.pmf(k,mu,loc=0)
# Out:
# 0.011612348610402475

# %%
#poisson.pmf(k, mu, loc) // pmf(k, mu, loc=0)
mu=300/320
stats.poisson.pmf(1,mu,loc=0)
# Out:
# 0.3671302750094991

# %% [markdown]
# #### What is the probability of getting 60 visits?

# %% [markdown]
# #### Plot the distribution of the probability for getting 0-1000 visits.
#
# *Hints:*
#
# - Create a list to store the Poisson distribution probabilities for n=0 to 1000. Then plot the probabilities.
#
# - Your plot should look like below:
#
# ![poisson distribution](ch-3.png)

# %%
mu = 300
k= range(0,1000)
poisson=stats.poisson.pmf(k,mu,loc=0)

x = np.arange(0,1000)
sns.lineplot(x,poisson)
