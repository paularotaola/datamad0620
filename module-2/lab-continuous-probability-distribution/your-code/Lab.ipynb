# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Uniform Distribution

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.22450228 2.40748548 2.99339589 2.33640465 2.40745099 2.62408367
#  2.26674069 2.98855224 2.56402677 2.48320528]

# %% [markdown]
# Your task:
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#
#
# - It should accept 3 parameters:
# -    bottom - the lower boundary of the generated numbers
# -    ceiling - the upper boundary of the generated numbers
# -    count - how many numbers to generate
# - It should return an array of uniformly distributed random numbers
#
#
# 2. Call your function with 2 sets of params below:
#
#
# - bottom=10, ceiling=15, count=100
# - bottom=10, ceiling=60, count=1,000
#
#
# 3. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below

# %%
def uniform_numbers(bottom, ceiling, count):
    count = uniform.rvs(size=10)
    randoms  = bottom + (ceiling-bottom)*count
    return randoms

example_1= uniform_numbers(10,15,100)
example_2= uniform_numbers(10,60,1000)

plt.subplot(1,2,1)
sns.distplot(example_1, bins=10)

plt.subplot(1,2,2)
sns.distplot(example_2, bins=10)

# %% [markdown]
# ## Normal Distribution

# %% [markdown]
# ## Normal Distribution of Real Data

# %% [markdown]
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise
#
# First import vehicles.csv. Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
data = pd.read_csv("vehicles.csv")
fuel = data["Fuel Barrels/Year"]

sns.distplot(fuel, bins=16)

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
CO2 = data["CO2 Emission Grams/Mile"]

sns.distplot(CO2, bins=16)

# %% [markdown]
# 3. Combined MPG

# %%
MPG = data["Combined MPG"]

sns.distplot(MPG, bins=16)

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %% [markdown]
# ## Exponential Distribution of Real Data

# %%
np.random.exponential()
# Out:
# 2.8090118712107155

# %% [markdown]
# ## Exponential Distribution¶ of Real Data

# %% [markdown]
# 1. Using numpy.random.exponential, create a function that returns a list of numbers exponentially distributed with the mean of 10.
# 2. Use the function to generate two number sequences with the size of 10 and 100.
# 3. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
